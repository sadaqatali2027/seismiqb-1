# %% [markdown]
# # Horizonts modelling dataset

# %% [markdown]
# # Content
#
# * [Cube 1](cube_1)
# * [Cube 2](cube_2)
# * [Cube 3](cube_3)
# * [Cube 4](cube_4)
# * [Cube 5](cube_5)
# * [Cube 6](cube_6)
# * [Cube 7](cube_7)

# %% [markdown]
# | Cube alias | Filename|  Size | Shape (ilines, xlines, height) | Size of labels |
# | :------ | --- | ----: | ----: | ----: |
# | CUBE_1 | E_anon.hdf5 | 21 GB | 2563, 1409, 1501 | 1.1 GB |
# | CUBE_2 | M_cube.hdf5 | 2.8 GB | 418, 869, 2001 | 0.07 GB |
# | CUBE_3 | P_cube.hdf5 | 54 GB | 2737, 2599, 2001 | 0.68 GB |
# | CUBE_4 | R_cube.hdf5 | 8.2 GB | 1472, 1380, 1071 | 0.81 GB |
# | CUBE_5 | AMP.hdf5 | 5.4 GB | 1010, 715, 2000 | 0.02 GB |
# | CUBE_6 | T_cube.hdf5 | 2.6 GB | 2010, 1520, 226 | 0 GB |
# | CUBE_7 | R_cube.hdf5 | 3.8 GB | 668, 1896, 771 | 0.08 GB |

# %% [markdown]
# Each cube is located at `/notebooks/SEISMIC_DATA/` + `cube alias` + `filename`
#
# Labels for each cube are contained at `/notebooks/SEISMIC_DATA/` + `cube alias` + `BEST_HORIZONTS`

# %%
import sys
from tqdm import tqdm_notebook
from glob import glob
import matplotlib.pyplot as plt

sys.path.append('..')
from seismiqb.batchflow import L, D, Pipeline, FilesIndex
from seismiqb import SeismicCropBatch, SeismicGeometry, SeismicCubeset

# %% [markdown]
# <a id='cube_1'></a>
# # Cube 1

# %% [markdown]
# First of all, we make an index with `.hdf5` cube. `SeismicCubeset` provides lots of processing actions for different types of seismic information (cubes in different formats, labels).

# %%
# %%time
path_data = '/notebooks/SEISMIC_DATA/CUBE_1/E_anon.hdf5'

dsi = FilesIndex(path=[path_data], no_ext=True)
ds = SeismicCubeset(dsi)
ds = ds.load()
# ~30 seconds
# Out:
# CPU times: user 25.4 s, sys: 7.08 s, total: 32.5 s
# Wall time: 34.1 s

# %% [markdown]
# Lets look at different parameters of the cube:

# %%
geometry = ds.geometries[ds.indices[0]]
geometry.log(print)
# Out:
# Info for cube: /notebooks/SEISMIC_DATA/CUBE_1/E_anon.hdf5
# Depth of one trace is: 1501
# Time delay: 50
# Sample rate: 2
# Number of ILINES: 2563
# Number of XLINES: 1409
# ILINES range from 24 to 2586
# ILINES range from 19 to 1427

# %% [markdown]
# Some of the (iline, xline) points have at least one hand-labeled horizon, while some of them don't. We can look at the cube 'from above' to check size of labeled area:

# %%
ds.show_labels()

# %% [markdown]
# Time to look at sample of slide from the cube:

# %%
ds.show_slide(iline=1000)
# Out:
# Image from E_anon

# %% [markdown]
# This cube is the best one in terms of quality of labels/amount of labels.

# %% [markdown]
# <a id='cube_1'></a>
# # Cube 2

# %%
# %%time
path_data = '/notebooks/SEISMIC_DATA/CUBE_2/M_cube.hdf5'

dsi = FilesIndex(path=[path_data], no_ext=True)
ds = SeismicCubeset(dsi)
ds = ds.load()
# ~3 seconds
# Out:
# CPU times: user 2.05 s, sys: 284 ms, total: 2.33 s
# Wall time: 2.44 s

# %%
geometry = ds.geometries[ds.indices[0]]
geometry.log(print)
# Out:
# Info for cube: /notebooks/SEISMIC_DATA/CUBE_2/M_cube.hdf5
# Depth of one trace is: 2001
# Time delay: 0
# Sample rate: 2
# Number of ILINES: 418
# Number of XLINES: 869
# ILINES range from 1084 to 1501
# ILINES range from 558 to 1426

# %%
ds.show_labels()

# %%
ds.show_slide(iline=250)
# Out:
# Image from M_cube

# %% [markdown]
# Something is off with the connection between cube coordinates and labels coordinates. Despite that, cube is very small and amount of labels is even smaller, so this cube is usually held out for visual testing.

# %% [markdown]
# <a id='cube_3'></a>
# # Cube 3

# %%
# %%time
path_data = '/notebooks/SEISMIC_DATA/CUBE_3/P_cube.hdf5'

dsi = FilesIndex(path=[path_data], no_ext=True)
ds = SeismicCubeset(dsi)
ds = ds.load()
# ~23 seconds
# Out:
# CPU times: user 17.5 s, sys: 4.09 s, total: 21.6 s
# Wall time: 22.6 s

# %%
geometry = ds.geometries[ds.indices[0]]
geometry.log(print)
# Out:
# Info for cube: /notebooks/SEISMIC_DATA/CUBE_3/P_cube.hdf5
# Depth of one trace is: 2001
# Time delay: 0
# Sample rate: 2
# Number of ILINES: 2737
# Number of XLINES: 2599
# ILINES range from 1709 to 4445
# ILINES range from 1227 to 3825

# %%
ds.show_labels()

# %%
ds.show_slide(iline=250)
# Out:
# Image from P_cube

# %% [markdown]
# Almost all of the horizons are very plain, and data from this cube does not generalize very well to the others.

# %% [markdown]
# <a id='cube_4'></a>
# # Cube 4

# %%
# %%time
path_data = '/notebooks/SEISMIC_DATA/CUBE_4/R_cube.hdf5'

dsi = FilesIndex(path=[path_data], no_ext=True)
ds = SeismicCubeset(dsi)
ds = ds.load()
# ~35 seconds
# Out:
# CPU times: user 13.7 s, sys: 3.27 s, total: 17 s
# Wall time: 18.1 s

# %%
geometry = ds.geometries[ds.indices[0]]
geometry.log(print)
# Out:
# Info for cube: /notebooks/SEISMIC_DATA/CUBE_4/R_cube.hdf5
# Depth of one trace is: 1071
# Time delay: -280
# Sample rate: 4
# Number of ILINES: 1472
# Number of XLINES: 1380
# ILINES range from 1001 to 2472
# ILINES range from 5001 to 6380

# %%
ds.show_labels()

# %%
ds.show_slide(iline=1250)
# Out:
# Image from R_cube

# %% [markdown]
# Labels for this cube contain not only most visible horizons (like for others), but also outlines for different structures (e.g. salt). This cube has a good ratio between cube and labels sizes, but quality of labelling is lacking, as evident on the picture above.

# %% [markdown]
# <a id='cube_5'></a>
# # Cube 5

# %%
# %%time
path_data = '/notebooks/SEISMIC_DATA/CUBE_5/AMP.hdf5'

dsi = FilesIndex(path=[path_data], no_ext=True)
ds = SeismicCubeset(dsi)
ds = ds.load()
# ~2 seconds
# Out:
# CPU times: user 1.48 s, sys: 84 ms, total: 1.56 s
# Wall time: 1.64 s

# %%
geometry = ds.geometries[ds.indices[0]]
geometry.log(print)
# Out:
# Info for cube: /notebooks/SEISMIC_DATA/CUBE_5/AMP.hdf5
# Depth of one trace is: 2000
# Time delay: 0
# Sample rate: 2.0
# Number of ILINES: 1010
# Number of XLINES: 715
# ILINES range from 1 to 1010
# ILINES range from 1 to 715

# %%
ds.show_labels(hor_idx=3)

# %%
ds.show_slide(iline=777)
# Out:
# Image from AMP

# %% [markdown]
# Labels for this cube are not interpolated correctly.

# %% [markdown]
# <a id='cube_6'></a>
# # Cube 6

# %%
# %%time
path_data = '/notebooks/SEISMIC_DATA/CUBE_6/T_cube.hdf5'

dsi = FilesIndex(path=[path_data], no_ext=True)
ds = SeismicCubeset(dsi)
ds = ds.load_geometries()
# Out:
# CPU times: user 0 ns, sys: 32 ms, total: 32 ms
# Wall time: 79.2 ms

# %%
geometry = ds.geometries[ds.indices[0]]
geometry.log(print)
# Out:
# Info for cube: /notebooks/SEISMIC_DATA/CUBE_6/T_cube.hdf5
# Depth of one trace is: 226
# Time delay: 1900
# Sample rate: 2.0
# Number of ILINES: 2010
# Number of XLINES: 1520
# ILINES range from 1 to 2010
# ILINES range from 1 to 1520

# %%
ds.show_slide(iline=100)
# Out:
# Image from T_cube

# %% [markdown]
# Unfortunately, there are no labeled horizons for this cube. Yet, it still can be used for testing purposes.

# %% [markdown]
# <a id='cube_7'></a>
# # Cube 7

# %%
# %%time
path_data = '/notebooks/SEISMIC_DATA/CUBE_7/S_cube.hdf5'

dsi = FilesIndex(path=[path_data], no_ext=True)
ds = SeismicCubeset(dsi)
ds = ds.load()
# ~6 seconds
# Out:
# CPU times: user 4.97 s, sys: 724 ms, total: 5.69 s
# Wall time: 5.93 s

# %%
geometry = ds.geometries[ds.indices[0]]
geometry.log(print)
# Out:
# Info for cube: /notebooks/SEISMIC_DATA/CUBE_7/S_cube.hdf5
# Depth of one trace is: 771
# Time delay: -850
# Sample rate: 5
# Number of ILINES: 688
# Number of XLINES: 1896
# ILINES range from 1802 to 2489
# ILINES range from 1577 to 3472

# %%
ds.show_labels()

# %%
ds.show_slide(iline=555)
# Out:
# Image from S_cube

# %% [markdown]
# Some of the horizons seem a bit off.
